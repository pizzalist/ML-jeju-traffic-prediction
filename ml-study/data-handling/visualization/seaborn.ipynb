# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
fmri = sns.load_dataset("fmri")

# %%
sns.lineplot(x="timepoint", y="signal",data=fmri)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
fmri.sample(n=10, random_state=1)
# Out:
#     subject  timepoint event    region    signal
# 806      s6         18   cue  parietal  0.019532
# 691      s5         15   cue   frontal -0.019507
# 148      s5          8  stim  parietal  0.006805
# 676     s13          0   cue  parietal -0.018394
# 156     s11          7  stim  parietal  0.254042
# 27       s1         17  stim  parietal -0.038021
# 200     s11          4  stim  parietal  0.087175
# 262      s3          0  stim  parietal -0.008576
# 94       s4         12  stim  parietal -0.090036
# 339      s4          5  stim   frontal  0.455575

# %%
sns.lineplot(x="timepoint", y="signal", hue="event", data=fmri)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "time", data = tips)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y= "tip", hue = "time", hue_order=["Lunch", "Dinner"], data = tips)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.countplot(x= "smoker", data = tips)
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x = "smoker", hue = "time", data = tips)
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='count'>

# %%
sns.barplot(x = "day", y = "tip", hue = "sex", data = tips)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.set(style = "darkgrid")
sns.displot(tips["total_bill"])

# %%
sns.distplot(tips["total_bill"], bins = 5)
# Out:
# /var/folders/vs/d7h80pg10h31n7bq9nk3bhxc0000gn/T/ipykernel_34960/4011064407.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"], bins = 5)
# <AxesSubplot: xlabel='total_bill', ylabel='Density'>

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights)
# Out:
# /var/folders/vs/d7h80pg10h31n7bq9nk3bhxc0000gn/T/ipykernel_34960/3447772575.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("month", "year", "passengers")

# %%
sns.kdeplot(tips["total_bill"], shade = True, )
# Out:
# /var/folders/vs/d7h80pg10h31n7bq9nk3bhxc0000gn/T/ipykernel_34960/400586585.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["total_bill"], shade = True, )
# <AxesSubplot: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(tips["total_bill"], tips["tip"], shade = True )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.kdeplot(tips["total_bill"], tips["tip"], shade = True )
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # ??

# %% [markdown]
# ## seaborn - predefined plots

# %% [markdown]
# ### Violinplot - boxplot에 distribution을 함께 표현

# %%
sns.boxplot(x=tips["total_bill"])
# Out:
# <AxesSubplot: xlabel='total_bill'>

# %%
sns.violinplot(x=tips["total_bill"])
# Out:
# <AxesSubplot: xlabel='total_bill'>

# %%
ax = sns.violinplot(x = "day", y = "total_bill", hue = "smoker" , data = tips,
                    palette = "muted")

# %% [markdown]
# ### Swarmplot - 분포와 함께 scatter를 함께 표현

# %%
ax = sns.swarmplot(x = tips["total_bill"])

# %%
ax = sns.swarmplot(x = "day", y = "total_bill", hue = "sex", data = tips)

# %%
ax = sns.boxplot(x = "tip", y = "day", data = tips, whis = np.inf)
ax = sns.stripplot(x = "tip", y = "day", data = tips, color = ".3")

# %% [markdown]
# ## Pointplot - categor별로 numeric의 평균, 신뢰구간 표시

# %%
ax = sns.pointplot(x = "time", y = "total_bill", data = tips)

# %%
ax = sns.pointplot(x = "time", y = "total_bill", hue = "smoker",
                            data = tips,
                            markers = ["o", "^"],
                            linestyles= ["-", "--"])

# %% [markdown]
# ### regplot - scatter + 선형함수를 함께 표시

# %%
ax = sns.regplot(x = "total_bill", y = "tip", data = tips)

# %%
ax = sns.regplot(x = "size", y = "total_bill", data = tips,
                    x_estimator= np.mean)

# %% [markdown]
# ## relplot

# %%
g = sns.relplot(x="total_bill", y="tip", hue="day", col="time", data=tips)

# %%
g = sns.relplot(x="total_bill", y="tip", hue="day", 
                col="time", row="sex", data=tips, height=3)

# %% [markdown]
# ## catplot - category 데이터 중심의 표시

# %%
exercise = sns.load_dataset("exercise")
g = sns.catplot(x= "time", y = "pulse", hue = "kind", data = exercise)

# %%
titanic = sns.load_dataset("titanic")
g = sns.catplot("alive", col = "deck", col_wrap=4,
                data= titanic[titanic.deck.notnull()],
                kind = "count", height = 2.5, aspect= .8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 titanic = sns.load_dataset("titanic")
# ----> 2 g = sns.catplot("alive", col = "deck", col_wrap=4,
#       3                 data= titanic[titanic.deck.notnull()],
#       4                 kind = "count", height = 2.5, aspect= .8)
#
# TypeError: catplot() got multiple values for argument 'data'

# %% [markdown]
# ### FacetGrid - 특정 조건에 따른 다양한 plot을 grid로 표시

# %%
g = sns.FacetGrid(tips, col="time", row="smoker")
g = g.map(plt.hist, "total_bill")

# %%
g = sns.FacetGrid(tips, col= "time", row="smoker")
g = g.map(plt.scatter, "total_bill", "tip", edgecolor="w")

# %%
att = sns.load_dataset("attention")
g = sns.FacetGrid(att, col="subject", col_wrap=5, height=1.5)
g = g.map(plt.plot, "solutions", "score", marker=".")

# %% [markdown]
# ### pairplot - 데이터 간의 상관관계 표시

# %%
iris = sns.load_dataset("iris")
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %% [markdown]
# ### lmplot - regression 모델과 category 데이터를 함께 표시

# %%
sns.lmplot(x="total_bill", y="tip", col="smoker", data=tips)

# %%
g = sns.lmplot(x="size", y="total_bill", hue="day", col="day",
                data=tips, height=6, aspect=.4, x_jitter=.1)
