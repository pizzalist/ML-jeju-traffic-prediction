# %% [markdown]
# # Visualization - codeborn

# %% [markdown]
# ### 데이터 프레임 세팅

# %%
column_list = ["course_id", "assignment_id", "student_id", "submission_id", "submit_date", "total_score", "started_date", "ended_date"]

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
import pymysql

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn = pymysql.connect(host = 'codeborn-bi-db.cvv1o1yrngie.ap-northeast-2.rds.amazonaws.com',
                    port = 3306,
                    user = 'pidgeot',
                    password = 'bt3c1ZsFB1bQ',
                    db = 'codeborn')

# %%
df_assignments = pd.read_sql_query("select * from assignments;", conn)
df_relationship = pd.read_sql_query("select * from student_course_relation;", conn)
df_submissions = pd.read_sql_query("select * from submissions;", conn)

# %% [markdown]
# assignments와 submissions를 합친 테이블 생성

# %%
df_merge1 = pd.merge(df_assignments, df_submissions, on=["assignment_id"], how="inner")
df_merge1[column_list]
# Out:
#        course_id  assignment_id  student_id  submission_id  \
# 0         123456              1           1              1
# 1         123456              1           2              4
# 2         123456              1          11             10
# 3         123456              1          11             11
# 4         123456              1          43            288
# ...          ...            ...         ...            ...
# 21281  DSAA-2022             41         212          21363
# 21282  DSAA-2022             41         193          21364
# 21283  DSAA-2022             41         195          21365
# 21284  DSAA-2022             41         195          21366
# 21285  DSAA-2022             41         188          21367
#
#               submit_date  total_score started_date          ended_date
# 0     2020-07-13 15:00:00         10.0   2020-07-12 2020-07-20 23:59:59
# 1     2020-07-13 15:00:00         40.0   2020-07-12 2020-07-20 23:59:59
# 2     2021-09-18 11:07:58          NaN   2020-07-12 2020-07-20 23:59:59
# 3     2021-09-18 11:08:16          NaN   2020-07-12 2020-07-20 23:59:59
# 4     2021-09-23 11:34:39        100.0   2020-07-12 2020-07-20 23:59:59
# ...                   ...          ...          ...                 ...
# 21281 2022-12-10 23:42:26          NaN   2022-12-06 2022-12-11 00:00:00
# 21282 2022-12-10 23:46:36          NaN   2022-12-06 2022-12-11 00:00:00
# 21283 2022-12-11 14:58:52          0.0   2022-12-06 2022-12-11 00:00:00
# 21284 2022-12-11 15:18:28          0.0   2022-12-06 2022-12-11 00:00:00
# 21285 2022-12-11 15:38:49          0.0   2022-12-06 2022-12-11 00:00:00
#
# [21286 rows x 8 columns]

# %% [markdown]
# 조교 조건 적용

# %%
df_students = df_relationship[df_relationship["teaching_assistant"]==0]
df_students
# Out:
#      student_course_id  course_id  student_id  teaching_assistant
# 1                    2     123456           2                   0
# 2                    3     123456           3                   0
# 3                    4     123456           4                   0
# 4                    5     123457           5                   0
# 5                    6     123457           6                   0
# ..                 ...        ...         ...                 ...
# 207                211  DSAA-2022         209                   0
# 208                212  DSAA-2022         210                   0
# 209                213  DSAA-2022         211                   0
# 210                214  DSAA-2022         212                   0
# 211                215  DSAA-2022         213                   0
#
# [209 rows x 4 columns]

# %%
df_merge2 = pd.merge(df_merge1, df_students, on=["student_id", "course_id"], how="inner")
df_merge2 = df_merge2[(df_merge2["assignment_id"]!= 1)&(df_merge2["student_id"]!= 11)].reset_index()
df_merge2[column_list]
# Out:
#        course_id  assignment_id  student_id  submission_id  \
# 0      DSAA-2021              2          22             17
# 1      DSAA-2021              2          22             18
# 2      DSAA-2021              2          22             39
# 3      DSAA-2021              2          22             56
# 4      DSAA-2021              2          22             57
# ...          ...            ...         ...            ...
# 20011  DSAA-2022             40         212          21254
# 20012  DSAA-2022             40         212          21260
# 20013  DSAA-2022             40         212          21261
# 20014  DSAA-2022             41         212          21362
# 20015  DSAA-2022             41         212          21363
#
#               submit_date  total_score started_date          ended_date
# 0     2021-09-18 16:56:20         50.0   2021-09-19 2021-09-25 00:00:00
# 1     2021-09-18 16:57:14         50.0   2021-09-19 2021-09-25 00:00:00
# 2     2021-09-18 20:56:48         50.0   2021-09-19 2021-09-25 00:00:00
# 3     2021-09-18 23:08:05         75.0   2021-09-19 2021-09-25 00:00:00
# 4     2021-09-18 23:08:55          NaN   2021-09-19 2021-09-25 00:00:00
# ...                   ...          ...          ...                 ...
# 20011 2022-10-25 23:54:09          NaN   2022-10-12 2022-10-25 23:59:59
# 20012 2022-10-26 00:00:08          NaN   2022-10-12 2022-10-25 23:59:59
# 20013 2022-10-26 00:00:40          NaN   2022-10-12 2022-10-25 23:59:59
# 20014 2022-12-10 23:39:13          NaN   2022-12-06 2022-12-11 00:00:00
# 20015 2022-12-10 23:42:26          NaN   2022-12-06 2022-12-11 00:00:00
#
# [20016 rows x 8 columns]

# %% [markdown]
# 날짜 조건 적용

# %%
df_merge2["result"] = (df_merge2["submit_date"] >= df_merge2["started_date"])&(df_merge2["submit_date"] <= df_merge2["ended_date"])
df_merge2["result"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20011     True
# 20012    False
# 20013    False
# 20014     True
# 20015     True
# Name: result, Length: 20016, dtype: bool

# %%
df_condition = df_merge2[df_merge2["result"]].reset_index()
df_condition[column_list]
# Out:
#        course_id  assignment_id  student_id  submission_id  \
# 0      DSAA-2021              3          22             43
# 1      DSAA-2021              6          22            296
# 2      DSAA-2021              6          22            297
# 3      DSAA-2021              6          22            298
# 4      DSAA-2021              6          22            299
# ...          ...            ...         ...            ...
# 13949  DSAA-2022             40         212          21251
# 13950  DSAA-2022             40         212          21253
# 13951  DSAA-2022             40         212          21254
# 13952  DSAA-2022             41         212          21362
# 13953  DSAA-2022             41         212          21363
#
#               submit_date  total_score started_date          ended_date
# 0     2021-09-18 21:23:33        100.0   2021-09-01 2021-12-31 00:00:00
# 1     2021-09-23 12:13:46          NaN   2021-09-23 2021-09-24 00:00:00
# 2     2021-09-23 12:13:55          NaN   2021-09-23 2021-09-24 00:00:00
# 3     2021-09-23 12:15:50          NaN   2021-09-23 2021-09-24 00:00:00
# 4     2021-09-23 12:16:55          NaN   2021-09-23 2021-09-24 00:00:00
# ...                   ...          ...          ...                 ...
# 13949 2022-10-25 23:53:33          NaN   2022-10-12 2022-10-25 23:59:59
# 13950 2022-10-25 23:53:50          NaN   2022-10-12 2022-10-25 23:59:59
# 13951 2022-10-25 23:54:09          NaN   2022-10-12 2022-10-25 23:59:59
# 13952 2022-12-10 23:39:13          NaN   2022-12-06 2022-12-11 00:00:00
# 13953 2022-12-10 23:42:26          NaN   2022-12-06 2022-12-11 00:00:00
#
# [13954 rows x 8 columns]

# %% [markdown]
# 사용할 최종 데이터 프레임

# %%
df = df_condition[column_list]
df
# Out:
#        course_id  assignment_id  student_id  submission_id  \
# 0      DSAA-2021              3          22             43
# 1      DSAA-2021              6          22            296
# 2      DSAA-2021              6          22            297
# 3      DSAA-2021              6          22            298
# 4      DSAA-2021              6          22            299
# ...          ...            ...         ...            ...
# 13949  DSAA-2022             40         212          21251
# 13950  DSAA-2022             40         212          21253
# 13951  DSAA-2022             40         212          21254
# 13952  DSAA-2022             41         212          21362
# 13953  DSAA-2022             41         212          21363
#
#               submit_date  total_score started_date          ended_date
# 0     2021-09-18 21:23:33        100.0   2021-09-01 2021-12-31 00:00:00
# 1     2021-09-23 12:13:46          NaN   2021-09-23 2021-09-24 00:00:00
# 2     2021-09-23 12:13:55          NaN   2021-09-23 2021-09-24 00:00:00
# 3     2021-09-23 12:15:50          NaN   2021-09-23 2021-09-24 00:00:00
# 4     2021-09-23 12:16:55          NaN   2021-09-23 2021-09-24 00:00:00
# ...                   ...          ...          ...                 ...
# 13949 2022-10-25 23:53:33          NaN   2022-10-12 2022-10-25 23:59:59
# 13950 2022-10-25 23:53:50          NaN   2022-10-12 2022-10-25 23:59:59
# 13951 2022-10-25 23:54:09          NaN   2022-10-12 2022-10-25 23:59:59
# 13952 2022-12-10 23:39:13          NaN   2022-12-06 2022-12-11 00:00:00
# 13953 2022-12-10 23:42:26          NaN   2022-12-06 2022-12-11 00:00:00
#
# [13954 rows x 8 columns]

# %% [markdown]
# ## Pandas

# %% [markdown]
# ### 1. 각 코스별로 제출 학생의 숫자와 숙제 제출한 숙제를 출력하시오

# %%
students = df.groupby("course_id").agg({"student_id": "unique"})["student_id"].apply(lambda x: len(x))
submission = df.groupby("course_id")["submission_id"].count()

# %%
result1 = pd.concat([students, submission],  axis=1)
result1
# Out:
#            student_id  submission_id
# course_id
# DSAA-2021          38           2386
# DSAA-2022          31           1527
# PY-2022S           94          10041

# %% [markdown]
# ### 2. 각 코스별, 숙제별로 숙제를 가장 빨리 제출한 학생의 아이디와 제출한 시간을 출력하시오

# %%
submit = df.groupby(["course_id", "assignment_id"])["submit_date"].min()

# %%
result2 = pd.merge(df, submit, on="submit_date")[["course_id", "assignment_id", "student_id", "submit_date"]]
result2
# Out:
#     course_id  assignment_id  student_id         submit_date
# 0   DSAA-2021             18          30 2021-11-16 10:15:11
# 1   DSAA-2021              2          16 2021-09-20 00:53:24
# 2   DSAA-2021              3          15 2021-09-18 14:30:01
# 3   DSAA-2021             16          25 2021-10-31 19:17:00
# 4   DSAA-2021             11          21 2021-09-27 03:01:48
# 5   DSAA-2021             14          42 2021-10-07 10:06:31
# 6   DSAA-2021             10          24 2021-09-26 21:35:40
# 7   DSAA-2021              8          12 2021-09-23 16:06:08
# 8   DSAA-2021             13          52 2021-09-28 10:22:41
# 9   DSAA-2021              6          28 2021-09-23 10:35:09
# 10   PY-2022S             21          61 2022-04-08 20:01:05
# 11   PY-2022S             24          61 2022-04-06 09:55:13
# 12   PY-2022S             25          61 2022-04-06 09:54:52
# 13   PY-2022S             27          61 2022-04-08 19:56:55
# 14   PY-2022S             28          61 2022-04-08 20:01:15
# 15   PY-2022S             29          61 2022-04-08 20:44:27
# 16   PY-2022S             30          61 2022-04-27 11:31:46
# 17   PY-2022S             33          61 2022-05-04 11:03:22
# 18   PY-2022S             34          61 2022-05-29 17:27:49
# 19   PY-2022S             23         115 2022-04-06 11:11:21
# 20   PY-2022S             26         139 2022-04-13 00:45:50
# 21  DSAA-2022             35         182 2022-09-16 10:40:06
# 22  DSAA-2022             39         186 2022-10-05 15:19:33
# 23  DSAA-2022             37         200 2022-09-16 13:04:01
# 24  DSAA-2022             41         208 2022-12-06 19:31:49
# 25  DSAA-2022             36         199 2022-09-16 10:14:55
# 26  DSAA-2022             38         185 2022-09-20 16:57:08
# 27  DSAA-2022             40         209 2022-10-14 21:33:06

# %% [markdown]
# ### 3. 각 코스별, 숙제별로 학생들이 숙제를 제출한 회수를 출력하시오

# %%
result3 = df.pivot_table(["submission_id"],
            index=[df.course_id, df.assignment_id],
            aggfunc="count")
result3
# Out:
#                          submission_id
# course_id assignment_id
# DSAA-2021 2                        155
#           3                         40
#           6                        180
#           8                        109
#           10                        14
#           11                        26
#           13                       728
#           14                       790
#           16                       228
#           18                       116
# DSAA-2022 35                       391
#           36                       115
#           37                        90
#           38                       265
#           39                        84
#           40                       515
#           41                        67
# PY-2022S  21                         7
#           23                       732
#           24                      1330
#           25                      1319
#           26                       772
#           27                       435
#           28                        10
#           29                      1887
#           30                      2068
#           33                       677
#           34                       804

# %% [markdown]
# ### 4. 각 코스별, 숙제별, 학생별로 처음 만점이 될 때까지의 제출 횟수를 출력하시오 (단 만점이 아닌 경우에는 출력하지 않습니다.)

# %%
df4 = df.copy()
df4["perfect"] = (df4["total_score"] == 100)

# %%
first_perfect = df4[df4["perfect"]].pivot_table(["submit_date"],
                index=[df.course_id, df.assignment_id, df.student_id],
                aggfunc=np.min)

# %%
df4_merge = pd.merge(df4, first_perfect, on=["course_id", "assignment_id", "student_id"], how="left")
before_perfect = df4_merge[df4_merge["submit_date_x"] <= df4_merge["submit_date_y"]]

# %%
result4 = before_perfect.pivot_table(["submission_id"],
            index=[df.course_id, df.assignment_id, df.student_id],
            aggfunc="count")
result4
# Out:
#                                     submission_id
# course_id assignment_id student_id
# DSAA-2021 2             12                      2
#                         13                      1
#                         15                     13
#                         16                      4
#                         18                      7
# ...                                           ...
# PY-2022S  34            138                    26
#                         141                    50
#                         148                    26
#                         152                    12
#                         162                     8
#
# [525 rows x 1 columns]

# %% [markdown]
# ### 5. 각 코스별로 가장 숙제를 성적이 높으면서도, 가장 빠르게 숙제를 제출한 학생의 아이디, 만점개수 , 평균제출시간 을 출력하시오

# %% [markdown]
# - 가장 빠르게 숙제를 낸 학생의 기준이 멀까요?...............................................
# - 내맘대로 만점을 제일 빨리 낸 학생으로 구하기..

# %%
perfect_list = pd.merge(df, first_perfect, on=["assignment_id", "student_id", "submit_date"], how="right")
fast_submit = perfect_list.groupby(["course_id"]).agg({"submit_date":min})

# %%
fast_merge = pd.merge(df, fast_submit, on=["submit_date", "course_id"], how="right")
fast_perfact = fast_merge[fast_merge["total_score"]==100]
fast_perfact
# Out:
#    course_id  assignment_id  student_id  submission_id         submit_date  \
# 0  DSAA-2021              3          15             16 2021-09-18 14:30:01
# 2  DSAA-2022             36         204          18033 2022-09-16 10:34:09
# 3   PY-2022S             24          61           3199 2022-04-06 09:55:13
#
#    total_score started_date ended_date
# 0        100.0   2021-09-01 2021-12-31
# 2        100.0   2022-09-16 2022-09-18
# 3        100.0   2022-04-06 2022-04-16

# %%
df6_column = ["course_id", "student_id", "submit_date_x", "total_score_x", "started_date_x"]
df6 = pd.merge(df, fast_perfact, on=["course_id", "student_id"], how="right")[df6_column]

# %%
df6["submit_time"] = (df6["submit_date_x"] - df6["started_date_x"])
submit_average = df6.groupby(["course_id"]).agg({"student_id":"min","submit_time":np.mean})

# %%
df6["perfect_score"] = (df6["total_score_x"]==100)
count_perfect = df6[(df6["perfect_score"])].groupby(["course_id"]).agg({"perfect_score":"count"})

# %%
result5 = pd.concat([submit_average, count_perfect], axis=1)
result5
# Out:
#            student_id               submit_time  perfect_score
# course_id
# DSAA-2021          15 5 days 13:45:32.044776119              2
# DSAA-2022         204 0 days 10:51:52.666666666              1
# PY-2022S           61 6 days 02:38:53.674157303              1

# %% [markdown]
# ### 6. 각 숙제별로 학생들이 만점까지 걸리는 시간의 평균 점수를 계산하시오

# %%
perfect_list["time"] = (perfect_list["submit_date"] - perfect_list["started_date"])

# %%
result6 = perfect_list.groupby(["assignment_id"]).agg({"time":np.mean})
result6
# Out:
#                                     time
# assignment_id
# 2              3 days 10:41:26.588235294
# 3             21 days 11:59:29.304347826
# 6              0 days 17:40:46.210526315
# 8              0 days 21:32:01.666666666
# 10               27 days 06:10:53.625000
# 13                1 days 17:46:59.400000
# 14                6 days 05:58:10.200000
# 16             9 days 19:15:03.416666666
# 23             6 days 22:48:09.412698412
# 24                7 days 12:32:49.675000
# 25             8 days 14:39:47.458333333
# 26                5 days 13:00:47.125000
# 29            11 days 14:30:03.487179487
# 34               13 days 19:27:31.500000
# 35             0 days 20:05:59.263157894
# 36             0 days 11:13:55.708333333
# 37             1 days 13:36:33.666666666
# 38                       3 days 00:25:25
# 40             9 days 12:27:06.526315789

# %% [markdown]
# ### 7. 각 숙제별, 각 학생별로 학생들이 처음 제출 부터 만점까지 걸리는 횟수와 시간을 계산하시오 (단, 한번 제출에 만점일 경우 0으로 출력할 것)

# %%
df7 = before_perfect.copy()
df7["time"] = (df7["submit_date_y"] - df7["started_date"])

# %%
result7 = df7.groupby(["assignment_id", "student_id"]).agg({"submission_id":"count","time":"max"})
result7
# Out:
#                           submission_id             time
# assignment_id student_id
# 2             12                      2  3 days 19:32:11
#               13                      1  1 days 18:30:21
#               15                     13  1 days 02:53:28
#               16                      4  1 days 01:20:22
#               18                      7  1 days 18:49:30
# ...                                 ...              ...
# 40            205                    15 12 days 18:15:22
#               206                    13  7 days 22:33:04
#               208                    11 10 days 04:54:33
#               209                    18  3 days 11:30:53
#               210                    12  4 days 19:58:11
#
# [525 rows x 2 columns]

# %% [markdown]
# ### 8. 각 코스별, 각 숙제별로 학생들이 처음 제출한 시간과 마지막으로 제출한 시간을 출력하시오

# %%
result8 = df.groupby(["course_id", "assignment_id"]).agg({"submit_date":[min, max]})
result8
# Out:
#                                 submit_date
#                                         min                 max
# course_id assignment_id
# DSAA-2021 2             2021-09-20 00:53:24 2021-09-24 23:51:11
#           3             2021-09-18 14:30:01 2021-10-01 00:32:52
#           6             2021-09-23 10:35:09 2021-09-23 23:33:24
#           8             2021-09-23 16:06:08 2021-09-23 23:58:16
#           10            2021-09-26 21:35:40 2021-10-02 15:03:38
#           11            2021-09-27 03:01:48 2021-10-04 20:04:10
#           13            2021-09-28 10:22:41 2021-10-04 23:59:54
#           14            2021-10-07 10:06:31 2021-10-13 23:58:51
#           16            2021-10-31 19:17:00 2021-11-03 23:56:07
#           18            2021-11-16 10:15:11 2021-11-17 23:52:59
# DSAA-2022 35            2022-09-16 10:40:06 2022-09-17 19:59:15
#           36            2022-09-16 10:14:55 2022-09-17 02:40:58
#           37            2022-09-16 13:04:01 2022-09-17 23:35:14
#           38            2022-09-20 16:57:08 2022-09-22 23:56:29
#           39            2022-10-05 15:19:33 2022-10-05 23:43:59
#           40            2022-10-14 21:33:06 2022-10-25 23:57:49
#           41            2022-12-06 19:31:49 2022-12-10 23:46:36
# PY-2022S  21            2022-04-08 20:01:05 2022-04-08 20:37:34
#           23            2022-04-06 11:11:21 2022-04-08 23:46:25
#           24            2022-04-06 09:55:13 2022-04-15 23:58:27
#           25            2022-04-06 09:54:52 2022-04-15 23:58:40
#           26            2022-04-13 00:45:50 2022-04-29 21:39:40
#           27            2022-04-08 19:56:55 2022-04-22 23:58:04
#           28            2022-04-08 20:01:15 2022-04-13 08:21:20
#           29            2022-04-08 20:44:27 2022-04-22 23:58:50
#           30            2022-04-27 11:31:46 2022-05-06 17:48:25
#           33            2022-05-04 11:03:22 2022-05-13 23:15:23
#           34            2022-05-29 17:27:49 2022-06-12 23:18:12

# %% [markdown]
# ## Visulization

# %% [markdown]
# - 각 코스별로 제출 학생의 숫자와 숙제 평균 맞는 개수를 출력하시오
# - 각 코스별, 숙제별로 숙제를 가장 빨리 제출한 학생의 아이디와 제출한 시간을 출력하시오
# - 각 코스별, 숙제별로 학생들이 숙제를 제출한 회수를 출력하시오
# - 각 코스별, 숙제별, 학생별로 처음 만점이 될 때까지의 제출 횟수를 출력하시오
# 단 만점이 아닌 경우에는 출력하지 않습니다.
# - 각 코스별로 가장 숙제를 성적이 높으면서도, 가장 빠르게 숙제를 제출한 학생의 `아이디`, `만점개수` , `평균제출시간` 을 출력하시오
# - 각 숙제별로 학생들이 만점까지 걸리는 시간의 평균 점수를 계산하시오
# - 각 숙제별, 각 학생별로 학생들이 처음 제출 부터 만점까지 걸리는 횟수와 시간을 계산하시오, 단 여기서 한번 제출에서 만점일 경우에는 0으로 출력할 것
# - 각 코스별, 각 숙제별로 학생들이 처음 제출한 시간과 마지막으로 제출한 시간을 출력하시오

# %% [markdown]
# ### 1.

# %%
result1
# Out:
#            student_id  submission_id
# course_id
# DSAA-2021          38           2386
# DSAA-2022          31           1527
# PY-2022S           94          10041

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
sns.barplot(x="course_id", y="student_id", data=result1.reset_index())

plt.subplot(1,2,2)
sns.barplot(x="course_id", y="submission_id", data=result1.reset_index())
# Out:
# <AxesSubplot:xlabel='course_id', ylabel='submission_id'>

# %% [markdown]
# ### 2.

# %%
result2
# Out:
#     course_id  assignment_id  student_id         submit_date
# 0   DSAA-2021             18          30 2021-11-16 10:15:11
# 1   DSAA-2021              2          16 2021-09-20 00:53:24
# 2   DSAA-2021              3          15 2021-09-18 14:30:01
# 3   DSAA-2021             16          25 2021-10-31 19:17:00
# 4   DSAA-2021             11          21 2021-09-27 03:01:48
# 5   DSAA-2021             14          42 2021-10-07 10:06:31
# 6   DSAA-2021             10          24 2021-09-26 21:35:40
# 7   DSAA-2021              8          12 2021-09-23 16:06:08
# 8   DSAA-2021             13          52 2021-09-28 10:22:41
# 9   DSAA-2021              6          28 2021-09-23 10:35:09
# 10   PY-2022S             21          61 2022-04-08 20:01:05
# 11   PY-2022S             24          61 2022-04-06 09:55:13
# 12   PY-2022S             25          61 2022-04-06 09:54:52
# 13   PY-2022S             27          61 2022-04-08 19:56:55
# 14   PY-2022S             28          61 2022-04-08 20:01:15
# 15   PY-2022S             29          61 2022-04-08 20:44:27
# 16   PY-2022S             30          61 2022-04-27 11:31:46
# 17   PY-2022S             33          61 2022-05-04 11:03:22
# 18   PY-2022S             34          61 2022-05-29 17:27:49
# 19   PY-2022S             23         115 2022-04-06 11:11:21
# 20   PY-2022S             26         139 2022-04-13 00:45:50
# 21  DSAA-2022             35         182 2022-09-16 10:40:06
# 22  DSAA-2022             39         186 2022-10-05 15:19:33
# 23  DSAA-2022             37         200 2022-09-16 13:04:01
# 24  DSAA-2022             41         208 2022-12-06 19:31:49
# 25  DSAA-2022             36         199 2022-09-16 10:14:55
# 26  DSAA-2022             38         185 2022-09-20 16:57:08
# 27  DSAA-2022             40         209 2022-10-14 21:33:06

# %% [markdown]
# ### 3.

# %%
result3
# Out:
#                          submission_id
# course_id assignment_id
# DSAA-2021 2                        155
#           3                         40
#           6                        180
#           8                        109
#           10                        14
#           11                        26
#           13                       728
#           14                       790
#           16                       228
#           18                       116
# DSAA-2022 35                       391
#           36                       115
#           37                        90
#           38                       265
#           39                        84
#           40                       515
#           41                        67
# PY-2022S  21                         7
#           23                       732
#           24                      1330
#           25                      1319
#           26                       772
#           27                       435
#           28                        10
#           29                      1887
#           30                      2068
#           33                       677
#           34                       804

# %%
sns.barplot(x="assignment_id", y="submission_id", hue="course_id", data=result3.reset_index())
# Out:
# <AxesSubplot:xlabel='assignment_id', ylabel='submission_id'>

# %% [markdown]
# ### 4.

# %%
result4
# Out:
#                                     submission_id
# course_id assignment_id student_id
# DSAA-2021 2             12                      2
#                         13                      1
#                         15                     13
#                         16                      4
#                         18                      7
# ...                                           ...
# PY-2022S  34            138                    26
#                         141                    50
#                         148                    26
#                         152                    12
#                         162                     8
#
# [525 rows x 1 columns]

# %%
sns.boxplot(x="assignment_id", y="submission_id", hue="course_id", data=result4.reset_index(), whis=np.inf)
# Out:
# <AxesSubplot:xlabel='assignment_id', ylabel='submission_id'>

# %% [markdown]
# ### 5.

# %%
result5
# Out:
#            student_id               submit_time  perfect_score
# course_id
# DSAA-2021          15 5 days 13:45:32.044776119              2
# DSAA-2022         204 0 days 10:51:52.666666666              1
# PY-2022S           61 6 days 02:38:53.674157303              1

# %%
import datetime

# %%
result5["submit_time"].iloc[0]
# Out:
# Timedelta('5 days 13:45:32.044776119')

# %%
submit_time = pd.to_numeric(result5["submit_time"])/1000000000/60/60/24
result5_1 = pd.merge(result5, submit_time, on=["course_id"], how="inner")

# %%
pd.to_numeric(result5["submit_time"])/1000000000/60/60/24
# Out:
# course_id
# DSAA-2021    5.573288
# DSAA-2022    0.452693
# PY-2022S     6.110343
# Name: submit_time, dtype: float64

# %%
sns.barplot(x="perfect_score", y="submit_time_y", hue="course_id", data=result5_1.reset_index())
# Out:
# <AxesSubplot:xlabel='perfect_score', ylabel='submit_time_y'>

# %% [markdown]
# ### 6.

# %%
time = pd.to_numeric(result6["time"])/1000000000/60/60/24
result6_1 = pd.merge(result6, time, on=["assignment_id"], how="inner")

# %%
result6_1
# Out:
#                                   time_x     time_y
# assignment_id
# 2              3 days 10:41:26.588235294   3.445447
# 3             21 days 11:59:29.304347826  21.499645
# 6              0 days 17:40:46.210526315   0.736646
# 8              0 days 21:32:01.666666666   0.897242
# 10               27 days 06:10:53.625000  27.257565
# 13                1 days 17:46:59.400000   1.740965
# 14                6 days 05:58:10.200000   6.248729
# 16             9 days 19:15:03.416666666   9.802123
# 23             6 days 22:48:09.412698412   6.950109
# 24                7 days 12:32:49.675000   7.522797
# 25             8 days 14:39:47.458333333   8.610966
# 26                5 days 13:00:47.125000   5.542212
# 29            11 days 14:30:03.487179487  11.604207
# 34               13 days 19:27:31.500000  13.810781
# 35             0 days 20:05:59.263157894   0.837491
# 36             0 days 11:13:55.708333333   0.468006
# 37             1 days 13:36:33.666666666   1.567056
# 38                       3 days 00:25:25   3.017650
# 40             9 days 12:27:06.526315789   9.518826

# %%
sns.barplot(x="assignment_id", y="time_y", data=result6_1.reset_index())
# Out:
# <AxesSubplot:xlabel='assignment_id', ylabel='time_y'>

# %% [markdown]
# ### 7.

# %%
result7
# Out:
#                           submission_id             time
# assignment_id student_id
# 2             12                      2  3 days 19:32:11
#               13                      1  1 days 18:30:21
#               15                     13  1 days 02:53:28
#               16                      4  1 days 01:20:22
#               18                      7  1 days 18:49:30
# ...                                 ...              ...
# 40            205                    15 12 days 18:15:22
#               206                    13  7 days 22:33:04
#               208                    11 10 days 04:54:33
#               209                    18  3 days 11:30:53
#               210                    12  4 days 19:58:11
#
# [525 rows x 2 columns]

# %%
time = pd.to_numeric(result7["time"])/1000000000/60/60/24
result7_1 = pd.merge(result7, time, on=["assignment_id", "student_id"], how="inner")

# %%
result7_1
# Out:
#                           submission_id           time_x     time_y
# assignment_id student_id
# 2             12                      2  3 days 19:32:11   3.814016
#               13                      1  1 days 18:30:21   1.771076
#               15                     13  1 days 02:53:28   1.120463
#               16                      4  1 days 01:20:22   1.055810
#               18                      7  1 days 18:49:30   1.784375
# ...                                 ...              ...        ...
# 40            205                    15 12 days 18:15:22  12.760671
#               206                    13  7 days 22:33:04   7.939630
#               208                    11 10 days 04:54:33  10.204549
#               209                    18  3 days 11:30:53   3.479780
#               210                    12  4 days 19:58:11   4.832072
#
# [525 rows x 3 columns]

# %%
plt.figure(figsize=(16,10))

plt.subplot(1,2,1)
sns.boxplot(x="assignment_id", y="time_y", data=result7_1.reset_index())

plt.subplot(1,2,2)
sns.scatterplot(x="assignment_id", y="submission_id", data=result7_1.reset_index())
# Out:
# <AxesSubplot:xlabel='assignment_id', ylabel='submission_id'>

# %% [markdown]
# ### 8.

# %%
result8
# Out:
#                                 submit_date
#                                         min                 max
# course_id assignment_id
# DSAA-2021 2             2021-09-20 00:53:24 2021-09-24 23:51:11
#           3             2021-09-18 14:30:01 2021-10-01 00:32:52
#           6             2021-09-23 10:35:09 2021-09-23 23:33:24
#           8             2021-09-23 16:06:08 2021-09-23 23:58:16
#           10            2021-09-26 21:35:40 2021-10-02 15:03:38
#           11            2021-09-27 03:01:48 2021-10-04 20:04:10
#           13            2021-09-28 10:22:41 2021-10-04 23:59:54
#           14            2021-10-07 10:06:31 2021-10-13 23:58:51
#           16            2021-10-31 19:17:00 2021-11-03 23:56:07
#           18            2021-11-16 10:15:11 2021-11-17 23:52:59
# DSAA-2022 35            2022-09-16 10:40:06 2022-09-17 19:59:15
#           36            2022-09-16 10:14:55 2022-09-17 02:40:58
#           37            2022-09-16 13:04:01 2022-09-17 23:35:14
#           38            2022-09-20 16:57:08 2022-09-22 23:56:29
#           39            2022-10-05 15:19:33 2022-10-05 23:43:59
#           40            2022-10-14 21:33:06 2022-10-25 23:57:49
#           41            2022-12-06 19:31:49 2022-12-10 23:46:36
# PY-2022S  21            2022-04-08 20:01:05 2022-04-08 20:37:34
#           23            2022-04-06 11:11:21 2022-04-08 23:46:25
#           24            2022-04-06 09:55:13 2022-04-15 23:58:27
#           25            2022-04-06 09:54:52 2022-04-15 23:58:40
#           26            2022-04-13 00:45:50 2022-04-29 21:39:40
#           27            2022-04-08 19:56:55 2022-04-22 23:58:04
#           28            2022-04-08 20:01:15 2022-04-13 08:21:20
#           29            2022-04-08 20:44:27 2022-04-22 23:58:50
#           30            2022-04-27 11:31:46 2022-05-06 17:48:25
#           33            2022-05-04 11:03:22 2022-05-13 23:15:23
#           34            2022-05-29 17:27:49 2022-06-12 23:18:12

# %%
result8_1 = result8.copy().reset_index()

# %%
result8_1["minus"] = pd.to_numeric(result8_1["submit_date"]["max"] - result8_1["submit_date"]["min"])/1000000000/60/60/24
result8_1
# Out:
#     course_id assignment_id         submit_date                          minus
#                                             min                 max
# 0   DSAA-2021             2 2021-09-20 00:53:24 2021-09-24 23:51:11   4.956794
# 1   DSAA-2021             3 2021-09-18 14:30:01 2021-10-01 00:32:52  12.418646
# 2   DSAA-2021             6 2021-09-23 10:35:09 2021-09-23 23:33:24   0.540451
# 3   DSAA-2021             8 2021-09-23 16:06:08 2021-09-23 23:58:16   0.327870
# 4   DSAA-2021            10 2021-09-26 21:35:40 2021-10-02 15:03:38   5.727755
# 5   DSAA-2021            11 2021-09-27 03:01:48 2021-10-04 20:04:10   7.709977
# 6   DSAA-2021            13 2021-09-28 10:22:41 2021-10-04 23:59:54   6.567512
# 7   DSAA-2021            14 2021-10-07 10:06:31 2021-10-13 23:58:51   6.578009
# 8   DSAA-2021            16 2021-10-31 19:17:00 2021-11-03 23:56:07   3.193831
# 9   DSAA-2021            18 2021-11-16 10:15:11 2021-11-17 23:52:59   1.567917
# 10  DSAA-2022            35 2022-09-16 10:40:06 2022-09-17 19:59:15   1.388299
# 11  DSAA-2022            36 2022-09-16 10:14:55 2022-09-17 02:40:58   0.684757
# 12  DSAA-2022            37 2022-09-16 13:04:01 2022-09-17 23:35:14   1.438345
# 13  DSAA-2022            38 2022-09-20 16:57:08 2022-09-22 23:56:29   2.291215
# 14  DSAA-2022            39 2022-10-05 15:19:33 2022-10-05 23:43:59   0.350301
# 15  DSAA-2022            40 2022-10-14 21:33:06 2022-10-25 23:57:49  11.100498
# 16  DSAA-2022            41 2022-12-06 19:31:49 2022-12-10 23:46:36   4.176933
# 17   PY-2022S            21 2022-04-08 20:01:05 2022-04-08 20:37:34   0.025336
# 18   PY-2022S            23 2022-04-06 11:11:21 2022-04-08 23:46:25   2.524352
# 19   PY-2022S            24 2022-04-06 09:55:13 2022-04-15 23:58:27   9.585579
# 20   PY-2022S            25 2022-04-06 09:54:52 2022-04-15 23:58:40   9.585972
# 21   PY-2022S            26 2022-04-13 00:45:50 2022-04-29 21:39:40  16.870718
# 22   PY-2022S            27 2022-04-08 19:56:55 2022-04-22 23:58:04  14.167465
# 23   PY-2022S            28 2022-04-08 20:01:15 2022-04-13 08:21:20   4.513947
# 24   PY-2022S            29 2022-04-08 20:44:27 2022-04-22 23:58:50  14.134988
# 25   PY-2022S            30 2022-04-27 11:31:46 2022-05-06 17:48:25   9.261563
# 26   PY-2022S            33 2022-05-04 11:03:22 2022-05-13 23:15:23   9.508345
# 27   PY-2022S            34 2022-05-29 17:27:49 2022-06-12 23:18:12  14.243322

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="assignment_id", y="minus", hue="course_id", data=result8_1)
# Out:
# <AxesSubplot:xlabel='assignment_id', ylabel='minus'>
