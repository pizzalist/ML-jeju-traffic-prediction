# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_data = np.array([8759, 10132, 12078, 16430])
y_data = np.array([487, 612, 866, 1030])

plt.scatter(x_data,y_data, color='r', marker="s")
plt.show()

# %%
weight_0 = np.random.sample(5)
weight_1 = np.random.sample(5)
weight_0, weight_1
# Out:
# (array([0.61008445, 0.89318403, 0.64765037, 0.12637111, 0.54621428]),
#  array([0.88408402, 0.26411043, 0.10082783, 0.36077202, 0.85117536]))

# %%
y_hat_list = []
for w0, w1 in zip(weight_0, weight_1):
    y_hat_list.append(w0 + w1*x_data)
y_hat_list
# Out:
# [array([ 7744.30202645,  8958.1493876 , 10678.57689292, 14526.11055334]),
#  array([2314.23640677, 2676.86002189, 3190.81891119, 4340.22748584]),
#  array([ 883.79865104, 1022.23526754, 1218.44623309, 1657.24896798]),
#  array([3160.12848088, 3655.46846224, 4357.53081018, 5927.61063455]),
#  array([ 7455.99121968,  8624.65499322, 10281.04224981, 13985.35743002])]

# %%
plt.scatter(x_data, y_data, color='r', marker="s")
for y_hat in y_hat_list:
    plt.plot(x_data,y_hat)
plt.show()
