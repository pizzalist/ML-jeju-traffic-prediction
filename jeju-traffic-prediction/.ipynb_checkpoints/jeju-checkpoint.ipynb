# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import gc

import matplotlib.pyplot as plt
import seaborn as sns

import requests
import xmltodict
import json

from datetime import datetime

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # FutureWarning 제거
warnings.filterwarnings(action='ignore')

# %%
# def csv_to_parquet(csv_path, save_name):
#     df = pd.read_csv(csv_path)
#     df.to_parquet(f'./data/{save_name}.parquet')
#     del df
#     gc.collect()
#     print(save_name, 'Done.')

# %%
# csv_to_parquet('./data/train.csv', 'train')
# csv_to_parquet('./data/test.csv', 'test')

# %%
# train = pd.read_parquet('./data/train.parquet')
# test = pd.read_parquet('./data/test.parquet')

# %% [markdown]
# ### 데이터 불러오기

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %%
train[130:140]
# Out:
#                 id  base_date day_of_week  base_hour  lane_count  road_rating  \
# 130  TRAIN_0000130   20220118           화          8           1          107
# 131  TRAIN_0000131   20220212           토         18           2          103
# 132  TRAIN_0000132   20211203           금         12           2          103
# 133  TRAIN_0000133   20220220           일         11           1          103
# 134  TRAIN_0000134   20211030           토          9           1          106
# 135  TRAIN_0000135   20211008           금         21           2          106
# 136  TRAIN_0000136   20220731           일          9           3          103
# 137  TRAIN_0000137   20211013           수          3           2          103
# 138  TRAIN_0000138   20220104           화          2           1          106
# 139  TRAIN_0000139   20210902           목         21           3          106
#
#      road_name  multi_linked  connect_code  maximum_speed_limit  ...  \
# 130        한천로             0             0                 60.0  ...
# 131   일반국도11호선             0             0                 60.0  ...
# 132   일반국도12호선             0             0                 50.0  ...
# 133   일반국도16호선             0             0                 60.0  ...
# 134  지방도1120호선             0             0                 60.0  ...
# 135      중산간서로             0             0                 50.0  ...
# 136   일반국도16호선             0             0                 70.0  ...
# 137   일반국도12호선             0             0                 80.0  ...
# 138  지방도1120호선             0             0                 50.0  ...
# 139  지방도1132호선             0             0                 50.0  ...
#
#      road_type  start_node_name  start_latitude  start_longitude  \
# 130          0            제3한천교       33.502900       126.511234
# 131          0              영주교       33.305359       126.598914
# 132          0         외도초교앞삼거리       33.493661       126.433789
# 133          0            제2가시교       33.364471       126.769568
# 134          0            명월사거리       33.392366       126.263513
# 135          0           더럭초교차로       33.452396       126.344994
# 136          0             해안육교       33.465863       126.456384
# 137          3              한대교       33.417996       126.277208
# 138          3              명월교       33.393972       126.263060
# 139          3    삼양검은모래해변입구교차로       33.521399       126.587288
#
#     start_turn_restricted  end_node_name  end_latitude end_longitude  \
# 130                    없음          오라오거리     33.500330    126.505998
# 131                    없음        하례입구삼거리     33.300796    126.600332
# 132                    없음            외도교     33.494067    126.435871
# 133                    없음          성읍교차로     33.381730    126.792312
# 134                    없음           명월입구     33.393189    126.263195
# 135                    없음         쉬는팡교차로     33.451901    126.341998
# 136                    없음          제1해안교     33.463342    126.454106
# 137                    없음            한대교     33.418339    126.277314
# 138                    없음            명월교     33.394228    126.263042
# 139                    있음         삼양동사무소     33.521098    126.585400
#
#     end_turn_restricted  target
# 130                  있음    19.0
# 131                  없음    52.0
# 132                  없음    39.0
# 133                  없음    54.0
# 134                  없음    43.0
# 135                  없음    35.0
# 136                  없음    38.0
# 137                  없음    59.0
# 138                  없음    59.0
# 139                  없음    18.0
#
# [10 rows x 23 columns]

# %%
train.isnull().sum()
# Out:
# id                       0
# base_date                0
# day_of_week              0
# base_hour                0
# lane_count               0
# road_rating              0
# road_name                0
# multi_linked             0
# connect_code             0
# maximum_speed_limit      0
# vehicle_restricted       0
# weight_restricted        0
# height_restricted        0
# road_type                0
# start_node_name          0
# start_latitude           0
# start_longitude          0
# start_turn_restricted    0
# end_node_name            0
# end_latitude             0
# end_longitude            0
# end_turn_restricted      0
# target                   0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

items =  ['day_of_week', 'road_name', 'start_node_name', 'start_turn_restricted', 'end_node_name', 'end_turn_restricted']
train_label = train.copy()
encoder = LabelEncoder()

for i in items:
    encoder = LabelEncoder()
    encoder.fit(train_label[i])
    train_label[i] = encoder.transform(train_label[i])

train_label = train_label.drop("id", axis=1)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(train_label.corr(), linewidths = 0.1, vmax = 1.0, cmap = 'YlGn', linecolor = "white",annot=True)
plt.show()

# %% [markdown]
# 아래 컬럼과 상관관계를 가진다.
# - maximum_speed_limit
# - weight_restricted
# - road_type
# <br>상관관계 숫자 기준이 있어야 하나?

# %%
fig, axes = plt.subplots(3, figsize=(15,8))

sns.barplot(x='maximum_speed_limit',y='target',data=train,ax=axes[0]).set(title='maximum_speed_limit vs target')
sns.barplot(x='weight_restricted',y='target',data=train,ax=axes[1]).set(title='weight_restricted vs target')
sns.barplot(x='road_type',y='target',data=train,ax=axes[2]).set(title='road_type vs target')

plt.tight_layout()
plt.show()

# %% [markdown]
# ![한국도로공사](%ED%95%9C%EA%B5%AD%EB%8F%84%EB%A1%9C%EA%B3%B5%EC%82%AC.png)

# %% [markdown]
# 확인 해볼거
# - 추이 그래프 (날짜별, 시간대별, 요일별)
# - 공휴일
# - 눈, 기온, 비 순으로 교통량과 관계가 밀접
# - 전체 지도별 도로 표시
# - 컬럼이 너무 많아서 각 컬럼별 상관계수

# %% [markdown]
# ### 년도/월/일별 추이 그래프

# %%
train["datetime"] = pd.to_datetime(train["base_date"],format='%Y%m%d')

# %%
train['base_date'].min()
# Out:
# 20210901

# %%
train['base_date'].max()
# Out:
# 20220731

# %%
train['year'] = train['datetime'].dt.year
train['month'] = train['datetime'].dt.month
train['day'] = train['datetime'].dt.day

# %% [markdown]
# ###

# %%
train_date = train[['datetime','target']]
train_date = train_date.groupby('datetime').mean().reset_index()

train_time = train[['base_hour','target']]
train_time = train_time.groupby('base_hour').mean().reset_index()

train_day = train[['day_of_week','target']]
train_day = train_day.groupby('day_of_week').mean()
train_day = train_day.reindex(['월','화','수','목','금','토','일']).reset_index()

train_date.head()
# Out:
#     datetime     target
# 0 2021-09-01  43.760268
# 1 2021-09-02  43.769578
# 2 2021-09-03  43.692354
# 3 2021-09-04  44.084787
# 4 2021-09-05  44.136858

# %%
fig, axes = plt.subplots(3, figsize=(15,12))

sns.lineplot(x='datetime',y='target',data=train_date,ax=axes[0]).set(title='base_date vs target')
sns.lineplot(x='base_hour',y='target',data=train_time,ax=axes[1]).set(title='base_hour vs target')
sns.lineplot(x='day_of_week',y='target',data=train_day,ax=axes[2]).set(title='day_of_week vs target')

plt.rcParams['font.family'] = 'STIXNonUnicode'
plt.tight_layout()
plt.show()

# %%
train[(train['year']==2021) & (train['month']==11) & (train['day'] > 7)]
# Out:
# Empty DataFrame
# Columns: [id, base_date, day_of_week, base_hour, lane_count, road_rating, road_name, multi_linked, connect_code, maximum_speed_limit, vehicle_restricted, weight_restricted, height_restricted, road_type, start_node_name, start_latitude, start_longitude, start_turn_restricted, end_node_name, end_latitude, end_longitude, end_turn_restricted, target, datetime, year, month, day]
# Index: []
#
# [0 rows x 27 columns]

# %%
train[(train['year']==2022) & (train['month']==4) & (train['day'] > 31)]
# Out:
# Empty DataFrame
# Columns: [id, base_date, day_of_week, base_hour, lane_count, road_rating, road_name, multi_linked, connect_code, maximum_speed_limit, vehicle_restricted, weight_restricted, height_restricted, road_type, start_node_name, start_latitude, start_longitude, start_turn_restricted, end_node_name, end_latitude, end_longitude, end_turn_restricted, target, datetime, year, month, day]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# - 21년 11월, 22년 4월 데이터 비어있음
# - 데이터가 1년 주기도 돌지 못하기에 년도의 주기성으로 분석하기는 힘들것이라 판단

# %% [markdown]
# ### 그렇다면 날짜별로 위치가 빈 데이터도 있을까?

# %%
# fig, axes = plt.subplots(6, figsize=(15,30))

sns.lineplot(x='base_date',y='target',hue='road_name',data=train,ax=axes[0],legend=False).set(title='base_date vs target')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 3
#       1 # fig, axes = plt.subplots(6, figsize=(15,30))
# ----> 3 sns.lineplot(x='base_date',y='target',hue='road_name',data=train,ax=axes[0],legend=False).set(title='base_date vs target')
#       4 plt.show()
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/seaborn/relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/seaborn/relational.py:441, in _LinePlotter.plot(self, ax, kws)
#     438     grouped = sub_data.groupby(orient, sort=self.sort)
#     439     # Could pass as_index=False instead of reset_index,
#     440     # but that fails on a corner case with older pandas.
# --> 441     sub_data = grouped.apply(agg, other).reset_index()
#     442 else:
#     443     sub_data[f"{other}min"] = np.nan
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1353, in GroupBy.apply(self, func, *args, **kwargs)
#    1351 with option_context("mode.chained_assignment", None):
#    1352     try:
# -> 1353         result = self._python_apply_general(f, self._selected_obj)
#    1354     except TypeError:
#    1355         # gh-20949
#    1356         # try again, with .apply acting as a filtering
#    (...)
#    1360         # fails on *some* columns, e.g. a numeric operation
#    1361         # on a string grouper column
#    1363         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1367 @final
#    1368 def _python_apply_general(
#    1369     self,
#    (...)
#    1374     is_agg: bool = False,
#    1375 ) -> NDFrameT:
#    1376     """
#    1377     Apply function f in python space
#    1378
#    (...)
#    1400         data after applying f
#    1401     """
# -> 1402     values, mutated = self.grouper.apply(f, data, self.axis)
#    1403     if not_indexed_same is None:
#    1404         not_indexed_same = mutated
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/pandas/core/groupby/ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     765 # group might be modified
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     769     mutated = True
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1341, in GroupBy.apply.<locals>.f(g)
#    1338 @wraps(func)
#    1339 def f(g):
#    1340     with np.errstate(all="ignore"):
# -> 1341         return func(g, *args, **kwargs)
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/seaborn/_statistics.py:513, in EstimateAggregator.__call__(self, data, var)
#     511 elif self.error_method == "ci":
#     512     units = data.get("units", None)
# --> 513     boots = bootstrap(vals, units=units, func=self.estimator, **self.boot_kws)
#     514     err_min, err_max = _percentile_interval(boots, self.error_level)
#     516 return pd.Series({var: estimate, f"{var}min": err_min, f"{var}max": err_max})
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/seaborn/algorithms.py:96, in bootstrap(*args, **kwargs)
#      94 boot_dist = []
#      95 for i in range(int(n_boot)):
# ---> 96     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#      97     sample = [a.take(resampler, axis=0) for a in args]
#      98     boot_dist.append(f(*sample, **func_kwargs))
#
# File _generator.pyx:550, in numpy.random._generator.Generator.integers()
#
# File _bounded_integers.pyx:1228, in numpy.random._bounded_integers._rand_int64()
#
# File <__array_function__ internals>:200, in prod(*args, **kwargs)
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3076, in prod(a, axis, dtype, out, keepdims, initial, where)
#    2955 @array_function_dispatch(_prod_dispatcher)
#    2956 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2957          initial=np._NoValue, where=np._NoValue):
#    2958     """
#    2959     Return the product of array elements over a given axis.
#    2960
#    (...)
#    3074     10
#    3075     """
# -> 3076     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3077                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/miniconda3/envs/seminar/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 토/일 7월 빼고
# - 7월에 관광객이 많이 왔을것이기 때문에

# %%
train_exc_7 = train[train['month'] != 7]
train_day_exc_7 = train_exc_7[['day_of_week','target']]
train_day_exc_7 = train_day_exc_7.groupby('day_of_week').mean()
train_day_exc_7 = train_day_exc_7.reindex(['월','화','수','목','금','토','일']).reset_index()
train_day_exc_7
# Out:
#   day_of_week     target
# 0           월  43.164899
# 1           화  43.098667
# 2           수  43.170332
# 3           목  43.140092
# 4           금  42.879420
# 5           토  43.290647
# 6           일  43.606582

# %%
fig, axes = plt.subplots(2, figsize=(15,8))

sns.lineplot(x='day_of_week',y='target',data=train_day,ax=axes[0]).set(title='day_of_week vs target')
sns.lineplot(x='day_of_week',y='target',data=train_day_exc_7,ax=axes[1]).set(title='day_of_week vs target')

plt.rcParams['font.family'] = 'STIXNonUnicode'
plt.tight_layout()
plt.show()

# %% [markdown]
# - 7월과 주말의 연관성은 없어보인다.

# %% [markdown]
# - 관광객, 시민 들의 교통량 비교

# %% [markdown]
# -  월별 요일

# %% [markdown]
# ### 공휴일 시각화

# %% [markdown]
# 공휴일 데이터 불러오기

# %%
def get_holiday_data(year):
    url = 'http://apis.data.go.kr/B090041/openapi/service/SpcdeInfoService/getRestDeInfo'
    params = {
        'serviceKey': 'lUyD7/c6oiXRywzql7NJsMdnhrTjYOH+Rx/4siN3lV2/J2bWu4UfjpTnBTl150QccIo/8rglYGnTQW2XaKH81g==',
        'solYear': str(year),
        'numOfRows': '100' 
    }

    response = requests.get(url, params=params)
    xml_data = response.content
    json_data = json.dumps(xmltodict.parse(xml_data), indent=4)

    data = json.loads(json_data)

    items = data['response']['body']['items']['item']
    holiday_data = pd.DataFrame(items)

    return holiday_data

holiday_2021 = get_holiday_data(2021)
holiday_2022 = get_holiday_data(2022)

holiday_data = pd.concat([holiday_2021, holiday_2022],ignore_index=True)[['dateName','locdate']]
holiday_data["datetime"] = pd.to_datetime(holiday_data["locdate"],format='%Y%m%d')

holiday_data
# holiday_data.to_csv('./data/holiday.csv', index=False)
# Out:
#     dateName   locdate   datetime
# 0       1월1일  20210101 2021-01-01
# 1         설날  20210211 2021-02-11
# 2         설날  20210212 2021-02-12
# 3         설날  20210213 2021-02-13
# 4        삼일절  20210301 2021-03-01
# 5       어린이날  20210505 2021-05-05
# 6     부처님오신날  20210519 2021-05-19
# 7        현충일  20210606 2021-06-06
# 8        광복절  20210815 2021-08-15
# 9      대체공휴일  20210816 2021-08-16
# 10        추석  20210920 2021-09-20
# 11        추석  20210921 2021-09-21
# 12        추석  20210922 2021-09-22
# 13       개천절  20211003 2021-10-03
# 14     대체공휴일  20211004 2021-10-04
# 15       한글날  20211009 2021-10-09
# 16     대체공휴일  20211011 2021-10-11
# 17     기독탄신일  20211225 2021-12-25
# 18      1월1일  20220101 2022-01-01
# 19        설날  20220131 2022-01-31
# 20        설날  20220201 2022-02-01
# 21        설날  20220202 2022-02-02
# 22       삼일절  20220301 2022-03-01
# 23    대통령선거일  20220309 2022-03-09
# 24      어린이날  20220505 2022-05-05
# 25    부처님오신날  20220508 2022-05-08
# 26  전국동시지방선거  20220601 2022-06-01
# 27       현충일  20220606 2022-06-06
# 28       광복절  20220815 2022-08-15
# 29        추석  20220909 2022-09-09
# 30        추석  20220910 2022-09-10
# 31        추석  20220911 2022-09-11
# 32     대체공휴일  20220912 2022-09-12
# 33       개천절  20221003 2022-10-03
# 34       한글날  20221009 2022-10-09
# 35     대체공휴일  20221010 2022-10-10
# 36     기독탄신일  20221225 2022-12-25

# %%
# 공휴일이면 is_holiday에 'Y' 값 표시
train['is_holiday'] = train['datetime'].isin(holiday_data['datetime']).map({True: 'Y', False: 'N'})

# %% [markdown]
# - 데이터 확인 필요 없을수 있음

# %%
train_date = train[['datetime','target']]
train_date = train_date.groupby('datetime').mean().reset_index()
train_date['is_holiday'] = train_date['datetime'].isin(holiday_data['datetime']).map({True: 'Y', False: 'N'})

fig, axes = plt.subplots(3, figsize=(15,12))
sns.lineplot(x='datetime',y='target',data=train_date,ax=axes[0])
sns.lineplot(x='datetime',y='target',data=train_date,ax=axes[1])
sns.lineplot(x='datetime',y='target',data=train_date,ax=axes[2])

axes[0].set_xlim([datetime(2021, 9, 1), datetime(2021, 12, 31)])
axes[1].set_xlim([datetime(2022, 1, 1), datetime(2022, 3, 31)])
axes[2].set_xlim([datetime(2022, 4, 1), datetime(2022, 7, 31)])

for ax in axes:
    for _, row in train_date[train_date['is_holiday'] == 'Y'].iterrows():
        ax.axvline(x=row['datetime'], color='lightcoral', linestyle='--')

# plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 기온 - 교통량

# %%
# 제주도 기온, 강수 csv 파일 불러오기
def read_csv_jeju(filename):
    filename = pd.read_csv(f"./data/{filename}.csv", encoding='euc-kr')
    filename['날짜'] = filename['날짜'].str.replace('\t','')
    filename["날짜"] = pd.to_datetime(filename["날짜"],format='%Y-%m-%d')
    filename = filename.rename(columns={'날짜':'datetime'})
    return filename

# %%
temper = read_csv_jeju('temperature_jeju')[['datetime','평균기온(℃)']]
rain = read_csv_jeju('rain_jeju')[['datetime','강수량(mm)']]
rain.head()
# train = pd.merge(train, temper, on='datetime', how='left')
# train
# Out:
#     datetime  강수량(mm)
# 0 2021-09-01     14.5
# 1 2021-09-02     37.8
# 2 2021-09-03     21.8
# 3 2021-09-04      NaN
# 4 2021-09-05      7.6

# %% [markdown]
# - 스케일링
# - 이동평균 추가
# - 바 차트 만들기

# %%
merged_df = pd.merge(temper, rain, on='datetime', how='inner')
temp_rain = pd.merge(merged_df, train_date, left_on='datetime', right_on='datetime', how='inner')
temp_rain.head()
# Out:
#     datetime  평균기온(℃)  강수량(mm)     target is_holiday
# 0 2021-09-01     28.4     14.5  43.760268          N
# 1 2021-09-02     25.0     37.8  43.769578          N
# 2 2021-09-03     24.2     21.8  43.692354          N
# 3 2021-09-04     25.3      NaN  44.084787          N
# 4 2021-09-05     24.5      7.6  44.136858          N

# %%
# 온도와 target의 관계 시각화
plt.scatter(temp_rain['평균기온(℃)'], temp_rain['target'])
plt.xlabel('평균기온(℃)')
plt.ylabel('target')
plt.title('온도와 target의 관계')
plt.show()

# %%
# 년/월별 강수량 총 합
rain['year'] = rain['datetime'].dt.year
rain['month'] = rain['datetime'].dt.month
rain = rain[['year','month','강수량(mm)']].groupby(['year','month']).sum('강수량(mm)').reset_index()
rain
# Out:
#     year  month  강수량(mm)
# 0   2021      9    493.1
# 1   2021     10     32.1
# 2   2021     11     63.8
# 3   2021     12     31.4
# 4   2022      1     33.6
# 5   2022      2     25.1
# 6   2022      3     96.1
# 7   2022      4     84.0
# 8   2022      5      9.1
# 9   2022      6    143.6
# 10  2022      7    149.0

# %%
train_21_09 = train[(train['year'] == 2022) & (train['month'] == 7)]

train_date_21_09 = train_21_09[['datetime','target']]
train_date_21_09 = train_date_21_09.groupby('datetime').mean().reset_index()

plt.plot(train_date_21_09['datetime'], train_date_21_09['target'], marker='o', linestyle='-', label='target')
plt.xlabel('Date')
plt.ylabel('Target')
plt.title('Target Variation in September 2021')

# temp_rain 데이터프레임에서 강수량이 있는 날짜에 세로 선 그리기
for index, row in temp_rain.iterrows():
    if  (row['강수량(mm)'] >= 10):
        plt.axvline(x=row['datetime'], color='red', linestyle='--', alpha=0.5)
plt.xlim(train_date_21_09['datetime'].iloc[0], train_date_21_09['datetime'].iloc[-1])
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
train_21_09 = train[(train['year'] == 2021) & (train['month'] == 12)]

train_date_21_09 = train_21_09[['datetime','target']]
train_date_21_09 = train_date_21_09.groupby('datetime').mean().reset_index()

plt.plot(train_date_21_09['datetime'], train_date_21_09['target'], marker='o', linestyle='-', label='target')
plt.xlabel('Date')
plt.ylabel('Target')
plt.title('Target Variation in September 2021')

for index, row in temp_rain.iterrows():
    if (row['강수량(mm)'] >= 10):
        alpha = min(row['강수량(mm)'] / 50, 1.0)  # 알파 값 계산
        color = (1.0 - alpha, 0.0, alpha)  # RGB 값 계산 (파란색에서 빨간색으로 변화)
        plt.axvline(x=row['datetime'], color=color, linestyle='--', alpha=0.5)
plt.xlim(train_date_21_09['datetime'].iloc[0], train_date_21_09['datetime'].iloc[-1])
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
# 강수량과 target의 관계 시각화
plt.scatter(merged_df['강수량(mm)'], merged_df['target'])
plt.xlabel('강수량(mm)')
plt.ylabel('target')
plt.title('강수량과 target의 관계')
plt.show()

# %% [markdown]
# ### 지도 시각화
# - 아직 못함

# %%
import folium
from folium.plugins import HeatMap

# 지도 중심 위치 설정
center_lat = train['start_latitude'].mean()
center_lon = train['start_longitude'].mean()

# Folium 지도 객체 생성
m = folium.Map(location=[center_lat, center_lon], zoom_start=10)

# 도로 데이터를 순회하며 지도에 표시
for index, row in train.iterrows():
    start_lat = row['start_latitude']
    start_lon = row['start_longitude']
    end_lat = row['end_latitude']
    end_lon = row['end_longitude']
    target = row['target']
    
    # 시작점과 끝점을 선으로 연결
    folium.PolyLine(locations=[(start_lat, start_lon), (end_lat, end_lon)], color='blue').add_to(m)
    
    # 시작점과 끝점을 원으로 표시
    folium.CircleMarker(location=(start_lat, start_lon), radius=5, color='green', fill=True, fill_color='green').add_to(m)
    folium.CircleMarker(location=(end_lat, end_lon), radius=5, color='red', fill=True, fill_color='red').add_to(m)
    
    # 도로의 target을 색으로 표현
    heat_data = [[start_lat, start_lon, target], [end_lat, end_lon, target]]
    HeatMap(heat_data).add_to(m)

# %%
from sklearn.preprocessing import LabelEncoder

items =  ['day_of_week', 'road_name', 'start_node_name', 'start_turn_restricted', 'end_node_name', 'end_turn_restricted','is_holiday']
train_label = train.copy()
encoder = LabelEncoder()

for i in items:
    encoder = LabelEncoder()
    encoder.fit(train_label[i])
    train_label[i] = encoder.transform(train_label[i])
train_label = train_label.drop('id', axis=1)

# %%
train_label[train_label['vehicle_restricted'] != 0]
# Out:
# Empty DataFrame
# Columns: [base_date, day_of_week, base_hour, lane_count, road_rating, road_name, multi_linked, connect_code, maximum_speed_limit, vehicle_restricted, weight_restricted, height_restricted, road_type, start_node_name, start_latitude, start_longitude, start_turn_restricted, end_node_name, end_latitude, end_longitude, end_turn_restricted, target, datetime, year, month, day, is_holiday]
# Index: []
#
# [0 rows x 27 columns]

# %%
train_label = train_label.drop('vehicle_restricted', axis=1)
train_label.head()
# Out:
#    base_date  day_of_week  base_hour  lane_count  road_rating  road_name  \
# 0   20220623            1         17           1          106         46
# 1   20220728            1         21           2          103         34
# 2   20211010            4          7           2          103         36
# 3   20220311            0         13           2          107         57
# 4   20211005            6          8           2          103         35
#
#    multi_linked  connect_code  maximum_speed_limit  weight_restricted  ...  \
# 0             0             0                 60.0            32400.0  ...
# 1             0             0                 60.0                0.0  ...
# 2             0             0                 80.0                0.0  ...
# 3             0             0                 50.0                0.0  ...
# 4             0             0                 80.0                0.0  ...
#
#    end_node_name  end_latitude  end_longitude  end_turn_restricted  target  \
# 0            386     33.427749     126.662335                    0    52.0
# 1              2     33.504811     126.526240                    0    30.0
# 2            179     33.280072     126.362147                    0    61.0
# 3            203     33.245565     126.566228                    0    20.0
# 4            269     33.462677     126.330152                    0    38.0
#
#     datetime  year  month  day  is_holiday
# 0 2022-06-23  2022      6   23           0
# 1 2022-07-28  2022      7   28           0
# 2 2021-10-10  2021     10   10           0
# 3 2022-03-11  2022      3   11           0
# 4 2021-10-05  2021     10    5           0
#
# [5 rows x 26 columns]

# %% [markdown]
# - vehicle_restricted 모든값 0임

# %%
train_label[train_label['height_restricted'] != 0]
train_label = train_label.drop('height_restricted', axis=1)

# %%
train_label.corr()
# Out:
#                        base_date  day_of_week  base_hour  lane_count  \
# base_date               1.000000     0.036290  -0.008645    0.011463
# day_of_week             0.036290     1.000000   0.004889    0.001426
# base_hour              -0.008645     0.004889   1.000000   -0.029194
# lane_count              0.011463     0.001426  -0.029194    1.000000
# road_rating             0.018547    -0.002274   0.031658   -0.095717
# road_name              -0.003791     0.001307  -0.029342   -0.007497
# multi_linked            0.000832    -0.000084   0.005711   -0.026555
# connect_code           -0.010633    -0.000002  -0.002649   -0.029290
# maximum_speed_limit    -0.018713     0.001651  -0.036756    0.384002
# weight_restricted      -0.011030     0.000158  -0.003231   -0.177224
# road_type              -0.004599     0.000429  -0.007880   -0.050715
# start_node_name         0.002393     0.000105   0.004755   -0.061337
# start_latitude         -0.016818     0.001201  -0.021599    0.182674
# start_longitude        -0.004954     0.000656  -0.011478   -0.094806
# start_turn_restricted   0.010650     0.000879  -0.012476    0.292852
# end_node_name           0.003071     0.000212   0.005336   -0.071247
# end_latitude           -0.016786     0.001214  -0.021597    0.182330
# end_longitude          -0.004972     0.000664  -0.011489   -0.094732
# end_turn_restricted     0.010630     0.000949  -0.012589    0.312854
# target                 -0.033997     0.006397  -0.159407   -0.144256
# datetime                0.838149     0.014203  -0.012512    0.023900
# year                    0.999221     0.037503  -0.008213    0.010402
# month                  -0.859824    -0.047578   0.001738    0.003799
# day                     0.029167     0.013611   0.008077   -0.001085
# is_holiday             -0.033210     0.085495   0.026343   -0.000099
#
#                        road_rating  road_name  multi_linked  connect_code  \
# base_date                 0.018547  -0.003791      0.000832     -0.010633
# day_of_week              -0.002274   0.001307     -0.000084     -0.000002
# base_hour                 0.031658  -0.029342      0.005711     -0.002649
# lane_count               -0.095717  -0.007497     -0.026555     -0.029290
# road_rating               1.000000  -0.353247      0.024218     -0.054160
# road_name                -0.353247   1.000000     -0.030449      0.012323
# multi_linked              0.024218  -0.030449      1.000000     -0.001111
# connect_code             -0.054160   0.012323     -0.001111      1.000000
# maximum_speed_limit      -0.327474   0.143490     -0.020245     -0.015190
# weight_restricted        -0.118630   0.039103     -0.008790     -0.020491
# road_type                -0.125618   0.100424      0.042977     -0.025846
# start_node_name          -0.024628   0.013173      0.014888      0.015321
# start_latitude           -0.204793   0.061587     -0.014906      0.036623
# start_longitude           0.007401   0.136092      0.026895     -0.045695
# start_turn_restricted    -0.029050   0.023554     -0.007202     -0.016789
# end_node_name            -0.023999   0.010939      0.014908     -0.035967
# end_latitude             -0.204843   0.061585     -0.014907      0.037163
# end_longitude             0.007386   0.136035      0.026896     -0.044853
# end_turn_restricted      -0.029451   0.023933     -0.007203     -0.016791
# target                   -0.261693   0.116778     -0.008408      0.048348
# datetime                  0.028571  -0.005739     -0.000815     -0.013239
# year                      0.017585  -0.003605      0.000945     -0.010311
# month                    -0.003700   0.000905     -0.002193      0.005092
# day                       0.001480  -0.000947      0.000496     -0.000767
# is_holiday               -0.006821  -0.000273     -0.000273      0.002209
#
#                        maximum_speed_limit  weight_restricted  ...  \
# base_date                        -0.018713          -0.011030  ...
# day_of_week                       0.001651           0.000158  ...
# base_hour                        -0.036756          -0.003231  ...
# lane_count                        0.384002          -0.177224  ...
# road_rating                      -0.327474          -0.118630  ...
# road_name                         0.143490           0.039103  ...
# multi_linked                     -0.020245          -0.008790  ...
# connect_code                     -0.015190          -0.020491  ...
# maximum_speed_limit               1.000000           0.085080  ...
# weight_restricted                 0.085080           1.000000  ...
# road_type                         0.059511           0.792803  ...
# start_node_name                  -0.031340           0.084426  ...
# start_latitude                    0.253147          -0.128291  ...
# start_longitude                  -0.033018           0.034926  ...
# start_turn_restricted             0.094124          -0.119699  ...
# end_node_name                    -0.051493           0.085132  ...
# end_latitude                      0.252958          -0.128305  ...
# end_longitude                    -0.032907           0.034915  ...
# end_turn_restricted               0.104737          -0.119564  ...
# target                            0.425715           0.294092  ...
# datetime                         -0.031317          -0.018471  ...
# year                             -0.017561          -0.010346  ...
# month                             0.001396           0.000740  ...
# day                              -0.001759          -0.000207  ...
# is_holiday                        0.009261           0.003013  ...
#
#                        end_node_name  end_latitude  end_longitude  \
# base_date                   0.003071     -0.016786      -0.004972
# day_of_week                 0.000212      0.001214       0.000664
# base_hour                   0.005336     -0.021597      -0.011489
# lane_count                 -0.071247      0.182330      -0.094732
# road_rating                -0.023999     -0.204843       0.007386
# road_name                   0.010939      0.061585       0.136035
# multi_linked                0.014908     -0.014907       0.026896
# connect_code               -0.035967      0.037163      -0.044853
# maximum_speed_limit        -0.051493      0.252958      -0.032907
# weight_restricted           0.085132     -0.128305       0.034915
# road_type                   0.053671     -0.043430       0.033664
# start_node_name             0.310046     -0.035139       0.058852
# start_latitude             -0.037242      0.999106       0.127005
# start_longitude             0.063149      0.126900       0.999219
# start_turn_restricted       0.000424      0.282855       0.044240
# end_node_name               1.000000     -0.036092       0.063584
# end_latitude               -0.036092      1.000000       0.127098
# end_longitude               0.063584      0.127098       1.000000
# end_turn_restricted         0.005937      0.282649       0.044555
# target                      0.039770      0.036139      -0.001000
# datetime                    0.006450     -0.029415      -0.008541
# year                        0.002784     -0.015654      -0.004648
# month                       0.001044     -0.000037       0.000132
# day                        -0.000054     -0.001125      -0.000113
# is_holiday                 -0.001077      0.006879      -0.002501
#
#                        end_turn_restricted    target  datetime      year  \
# base_date                         0.010630 -0.033997  0.838149  0.999221
# day_of_week                       0.000949  0.006397  0.014203  0.037503
# base_hour                        -0.012589 -0.159407 -0.012512 -0.008213
# lane_count                        0.312854 -0.144256  0.023900  0.010402
# road_rating                      -0.029451 -0.261693  0.028571  0.017585
# road_name                         0.023933  0.116778 -0.005739 -0.003605
# multi_linked                     -0.007203 -0.008408 -0.000815  0.000945
# connect_code                     -0.016791  0.048348 -0.013239 -0.010311
# maximum_speed_limit               0.104737  0.425715 -0.031317 -0.017561
# weight_restricted                -0.119564  0.294092 -0.018471 -0.010346
# road_type                        -0.103781  0.200840 -0.004010 -0.004586
# start_node_name                   0.004197  0.029007  0.005655  0.002123
# start_latitude                    0.282798  0.036280 -0.029436 -0.015687
# start_longitude                   0.044308 -0.001168 -0.008513 -0.004631
# start_turn_restricted             0.405504 -0.156121  0.019465  0.009867
# end_node_name                     0.005937  0.039770  0.006450  0.002784
# end_latitude                      0.282649  0.036139 -0.029415 -0.015654
# end_longitude                     0.044555 -0.001000 -0.008541 -0.004648
# end_turn_restricted               1.000000 -0.162815  0.019369  0.009853
# target                           -0.162815  1.000000 -0.060606 -0.031676
# datetime                          0.019369 -0.060606  1.000000  0.816130
# year                              0.009853 -0.031676  0.816130  1.000000
# month                             0.000832 -0.000225 -0.446131 -0.879283
# day                              -0.000512 -0.011605  0.111779  0.027597
# is_holiday                       -0.000761  0.010936 -0.071621 -0.030749
#
#                           month       day  is_holiday
# base_date             -0.859824  0.029167   -0.033210
# day_of_week           -0.047578  0.013611    0.085495
# base_hour              0.001738  0.008077    0.026343
# lane_count             0.003799 -0.001085   -0.000099
# road_rating           -0.003700  0.001480   -0.006821
# road_name              0.000905 -0.000947   -0.000273
# multi_linked          -0.002193  0.000496   -0.000273
# connect_code           0.005092 -0.000767    0.002209
# maximum_speed_limit    0.001396 -0.001759    0.009261
# weight_restricted      0.000740 -0.000207    0.003013
# road_type              0.003837 -0.000432    0.001062
# start_node_name        0.001407 -0.000010   -0.000851
# start_latitude        -0.000004 -0.001119    0.006861
# start_longitude        0.000126 -0.000101   -0.002523
# start_turn_restricted  0.000882 -0.000410   -0.001246
# end_node_name          0.001044 -0.000054   -0.001077
# end_latitude          -0.000037 -0.001125    0.006879
# end_longitude          0.000132 -0.000113   -0.002501
# end_turn_restricted    0.000832 -0.000512   -0.000761
# target                -0.000225 -0.011605    0.010936
# datetime              -0.446131  0.111779   -0.071621
# year                  -0.879283  0.027597   -0.030749
# month                  1.000000 -0.029029    0.000727
# day                   -0.029029  1.000000   -0.154981
# is_holiday             0.000727 -0.154981    1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize=(30,20))
sns.heatmap(train_label.corr(),annot=True)
plt.show()

# %% [markdown]
# ### 데이터 전처리

# %%
str_col = ['day_of_week','start_turn_restricted','end_turn_restricted']
for i in str_col:
    le = LabelEncoder()
    le=le.fit(train[i])
    train[i]=le.transform(train[i])
    
    for label in np.unique(test[i]):
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    test[i]=le.transform(test[i])

# %%
y_train = train['target'] 

X_train = train.drop(['id','base_date', 'target','road_name', 'start_node_name', 'end_node_name','vehicle_restricted'], axis=1)

test = test.drop(['id','base_date', 'road_name', 'start_node_name', 'end_node_name','vehicle_restricted'], axis=1)

print(X_train.shape)
print(y_train.shape)
print(test.shape)
# Out:
# (4701217, 16)
# (4701217,)
# (291241, 16)

# %% [markdown]
# ### 모델 선언 및 학습

# %%
LR = lgb.LGBMRegressor(random_state=42).fit(X_train, y_train)

# %% [markdown]
# ### 추론

# %%
pred = LR.predict(test)

# %% [markdown]
# ### Submission

# %%
sample_submission = pd.read_csv('./data/sample_submission.csv')

# %%
sample_submission['target'] = pred
sample_submission.to_csv("./data/submit.csv", index = False)

# %%
sample_submission
# Out:
#                  id     target
# 0       TEST_000000  27.298710
# 1       TEST_000001  43.949243
# 2       TEST_000002  60.552621
# 3       TEST_000003  36.499322
# 4       TEST_000004  37.510570
# ...             ...        ...
# 291236  TEST_291236  45.902276
# 291237  TEST_291237  52.604831
# 291238  TEST_291238  21.964371
# 291239  TEST_291239  25.402628
# 291240  TEST_291240  41.406265
#
# [291241 rows x 2 columns]
